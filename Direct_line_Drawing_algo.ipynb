# %%
import matplotlib.pyplot as plt
import math

# %%
def DLA(x1, y1, x2, y2):
    
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    
    x_values = []
    y_values = []
    y_round_values = []
    
    if x1 > x2:
        x1, x2 = x2, x1
        y1, y2 = y2, y1
        
    x = x1
    y = y1
    
    while x <= x2:
        x_values.append(x)
        y_values.append(y)
        y_round_values.append(round(y))
        x += 1
        y = m * x + b
    
    return x_values, y_values, y_round_values

# %%
def plot_func(x_values, y_values, y_round_values):
    plt.plot(x_values, y_values, color = 'blue', marker = 'o')
    plt.plot(x_values, y_round_values, color = 'red', marker = 'o')
    plt.xlabel('x-axis')
    plt.ylabel('y-axis')
    plt.grid('true')
    plt.title('Direct Line drawing algorthm')

# %%
x1, y1 = 2, 3
x2, y2 = 10, 8
x_values, y_values, y_round_values = DLA(x1, y1, x2, y2)
print(x_values)
print(y_values)
plot_func(x_values, y_values, y_round_values)
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10]
# [3, 3.625, 4.25, 4.875, 5.5, 6.125, 6.75, 7.375, 8.0]

# %%
x1, y1 = 0,0
x2, y2 = 4,12
x_values, y_values, y_round_values = DLA(x1, y1, x2, y2)
print(x_values)
print(y_values)
plot_func(x_values, y_values, y_round_values)
# Out:
# [0, 1, 2, 3, 4]
# [0, 3.0, 6.0, 9.0, 12.0]
